# %%
from tastytrade import DXLinkStreamer
from tastytrade.dxfeed import Greeks, Quote
from tastytrade import Session, Account
from tastytrade.instruments import Option, Equity, NestedOptionChain, get_option_chain
from tastytrade.order import NewOrder, OrderAction, OrderTimeInForce, OrderType, PlacedOrderResponse

from lib import TTConfig, TTOption, TTOptionSide

from decimal import Decimal
from datetime import date, timedelta

from live_prices import TastytradeWrapper
from strategist import IronCondor, PositionManager
from account_updates import AccountUpdates

# %%
config = TTConfig(filename='tt.sandbox.config')
# config = TTConfig(filename='tt.config')
session = Session(config.username, config.password, is_test=not config.use_prod)

# %%
account = Account.get_accounts(session)[0]

# %%
full_chain = get_option_chain(session, 'SPXW')

# %%
options_for_today = full_chain[date.today() + timedelta(days=4)]
options_for_today
# Out:
# [Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C02400000', active=True, strike_price=Decimal('2400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C2400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P02400000', active=True, strike_price=Decimal('2400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P2400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C02600000', active=True, strike_price=Decimal('2600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C2600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P02600000', active=True, strike_price=Decimal('2600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P2600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C02800000', active=True, strike_price=Decimal('2800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C2800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P02800000', active=True, strike_price=Decimal('2800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P2800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C03000000', active=True, strike_price=Decimal('3000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C3000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P03000000', active=True, strike_price=Decimal('3000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P3000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C03200000', active=True, strike_price=Decimal('3200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C3200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P03200000', active=True, strike_price=Decimal('3200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P3200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C03400000', active=True, strike_price=Decimal('3400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C3400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P03400000', active=True, strike_price=Decimal('3400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P3400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C03600000', active=True, strike_price=Decimal('3600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C3600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P03600000', active=True, strike_price=Decimal('3600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P3600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C03800000', active=True, strike_price=Decimal('3800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C3800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P03800000', active=True, strike_price=Decimal('3800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P3800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04000000', active=True, strike_price=Decimal('4000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04000000', active=True, strike_price=Decimal('4000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04200000', active=True, strike_price=Decimal('4200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04200000', active=True, strike_price=Decimal('4200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04400000', active=True, strike_price=Decimal('4400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04400000', active=True, strike_price=Decimal('4400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04500000', active=True, strike_price=Decimal('4500.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4500', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04500000', active=True, strike_price=Decimal('4500.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4500', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04600000', active=True, strike_price=Decimal('4600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04600000', active=True, strike_price=Decimal('4600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04650000', active=True, strike_price=Decimal('4650.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4650', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04650000', active=True, strike_price=Decimal('4650.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4650', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04700000', active=True, strike_price=Decimal('4700.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4700', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04700000', active=True, strike_price=Decimal('4700.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4700', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04750000', active=True, strike_price=Decimal('4750.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4750', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04750000', active=True, strike_price=Decimal('4750.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4750', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04800000', active=True, strike_price=Decimal('4800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04800000', active=True, strike_price=Decimal('4800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04850000', active=True, strike_price=Decimal('4850.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4850', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04850000', active=True, strike_price=Decimal('4850.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4850', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04900000', active=True, strike_price=Decimal('4900.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4900', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04900000', active=True, strike_price=Decimal('4900.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4900', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C04950000', active=True, strike_price=Decimal('4950.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C4950', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P04950000', active=True, strike_price=Decimal('4950.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P4950', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05000000', active=True, strike_price=Decimal('5000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05000000', active=True, strike_price=Decimal('5000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05100000', active=True, strike_price=Decimal('5100.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5100', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05100000', active=True, strike_price=Decimal('5100.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5100', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05150000', active=True, strike_price=Decimal('5150.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5150', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05150000', active=True, strike_price=Decimal('5150.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5150', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05200000', active=True, strike_price=Decimal('5200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05200000', active=True, strike_price=Decimal('5200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05250000', active=True, strike_price=Decimal('5250.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5250', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05250000', active=True, strike_price=Decimal('5250.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5250', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05290000', active=True, strike_price=Decimal('5290.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5290', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05290000', active=True, strike_price=Decimal('5290.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5290', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05300000', active=True, strike_price=Decimal('5300.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5300', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05300000', active=True, strike_price=Decimal('5300.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5300', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05325000', active=True, strike_price=Decimal('5325.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5325', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05325000', active=True, strike_price=Decimal('5325.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5325', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05350000', active=True, strike_price=Decimal('5350.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5350', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05350000', active=True, strike_price=Decimal('5350.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5350', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05375000', active=True, strike_price=Decimal('5375.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5375', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05375000', active=True, strike_price=Decimal('5375.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5375', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05400000', active=True, strike_price=Decimal('5400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05400000', active=True, strike_price=Decimal('5400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P5400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C05425000', active=True, strike_price=Decimal('5425.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C5425', listed_market=None, halted_at=None, old_security_number=None),
# ...
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06200000', active=True, strike_price=Decimal('6200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06250000', active=True, strike_price=Decimal('6250.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6250', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06250000', active=True, strike_price=Decimal('6250.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6250', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06300000', active=True, strike_price=Decimal('6300.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6300', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06300000', active=True, strike_price=Decimal('6300.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6300', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06350000', active=True, strike_price=Decimal('6350.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6350', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06350000', active=True, strike_price=Decimal('6350.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6350', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06400000', active=True, strike_price=Decimal('6400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06400000', active=True, strike_price=Decimal('6400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06500000', active=True, strike_price=Decimal('6500.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6500', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06500000', active=True, strike_price=Decimal('6500.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6500', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06600000', active=True, strike_price=Decimal('6600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06600000', active=True, strike_price=Decimal('6600.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6600', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06800000', active=True, strike_price=Decimal('6800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C6800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P06800000', active=True, strike_price=Decimal('6800.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P6800', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C07000000', active=True, strike_price=Decimal('7000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C7000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P07000000', active=True, strike_price=Decimal('7000.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P7000', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C07200000', active=True, strike_price=Decimal('7200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C7200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P07200000', active=True, strike_price=Decimal('7200.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P7200', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C07400000', active=True, strike_price=Decimal('7400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.CALL: 'C'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206C7400', listed_market=None, halted_at=None, old_security_number=None),
#  Option(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P07400000', active=True, strike_price=Decimal('7400.0'), root_symbol='SPXW', underlying_symbol='SPX', expiration_date=datetime.date(2024, 12, 6), exercise_style='European', shares_per_contract=100, option_type=<OptionType.PUT: 'P'>, option_chain_type='Standard', expiration_type='Weekly', settlement_type='PM', stops_trading_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), market_time_instrument_collection='Cash Settled Equity Option', days_to_expiration=4, expires_at=datetime.datetime(2024, 12, 6, 21, 15, tzinfo=TzInfo(UTC)), is_closing_only=False, streamer_symbol='.SPXW241206P7400', listed_market=None, halted_at=None, old_security_number=None)]

# %%
op_pb = Option.get_option(session, 'SPXW  241206P05920000')
op_ps = Option.get_option(session, 'SPXW  241206P05950000')
op_cs = Option.get_option(session, 'SPXW  241206C06060000')
op_cb = Option.get_option(session, 'SPXW  241206C06090000')

# %%
position_to_open = IronCondor(op_pb, op_ps, op_cs, op_cb)

# %%
account_updates = await AccountUpdates.create(session, account)

# %%
position_manager = PositionManager(account_updates, position=position_to_open)

# %%
response = await position_manager.open_position(session, account, dry_run=False)
response
# Out:
# PlacedOrderResponse(buying_power_effect=BuyingPowerEffect(change_in_margin_requirement=Decimal('-3000.0'), change_in_buying_power=Decimal('-3002.124'), current_buying_power=Decimal('999989.752'), new_buying_power=Decimal('996987.628'), isolated_order_margin_requirement=Decimal('-3000.0'), is_spread=True, impact=Decimal('3002.124'), effect=<PriceEffect.DEBIT: 'Debit'>), order=PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.ROUTED: 'Routed'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 838000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=157998, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 816000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=None, complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None), fee_calculation=FeeCalculation(regulatory_fees=Decimal('-0.124'), clearing_fees=Decimal('-0.4'), commission=Decimal('-4.0'), proprietary_index_option_fees=Decimal('-2.6'), total_fees=Decimal('-7.124')), warnings=[], errors=None)

# %%
position_manager.get_open_order()
# Out:
# PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 956000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.44-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='43')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.46-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='45')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.47-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='46')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.45-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='44')])], id=157998, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 816000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 952000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None)

# %%
account.get_order_history(session)
# Out:
# [PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 956000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.44-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='43')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.46-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='45')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.47-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='46')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.45-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='44')])], id=157998, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 816000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 952000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 914000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.40-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='39')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.38-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='37')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.39-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='38')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.41-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='40')])], id=157995, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 772000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 911000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 605000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.34-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='33')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.36-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='35')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.37-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='36')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.35-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='34')])], id=157991, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 467000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 601000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 749000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.197-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='196')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06100000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.196-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='195')])], id=155520, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 617000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 745000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 170000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C05900000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.195-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='194')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.194-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='193')])], id=155519, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 25000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 166000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155135, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 51000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155134, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 475000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155133, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 872000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155132, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 57000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None)]

# %%
position_manager.opening_profit()
# Out:
# Decimal('0.07')

# %%
close_response = await position_manager.close_position(session, account, dry_run=False)
close_response
# Out:
# PlacedOrderResponse(buying_power_effect=BuyingPowerEffect(change_in_margin_requirement=Decimal('3000.0'), change_in_buying_power=Decimal('2991.876'), current_buying_power=Decimal('996989.628'), new_buying_power=Decimal('999981.504'), isolated_order_margin_requirement=Decimal('0.0'), is_spread=False, impact=Decimal('2991.876'), effect=<PriceEffect.CREDIT: 'Credit'>), order=PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.ROUTED: 'Routed'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 491000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=157999, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 470000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=None, complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None), fee_calculation=FeeCalculation(regulatory_fees=Decimal('-0.124'), clearing_fees=Decimal('-0.4'), commission=Decimal('0.0'), proprietary_index_option_fees=Decimal('-2.6'), total_fees=Decimal('-3.124')), warnings=[], errors=None)

# %%
position_manager.get_close_order()
# Out:
# PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 614000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.50-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='49')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.48-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='47')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.49-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='48')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.51-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='50')])], id=157999, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 470000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 610000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None)

# %%
position_manager.account_updates.orders.keys()
# Out:
# dict_keys([157998, 157999])

# %%
account.get_order_history(session)
# Out:
# [PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 614000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.50-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='49')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.48-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='47')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.49-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='48')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.51-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='50')])], id=157999, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 470000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 19, 46, 610000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 956000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.44-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='43')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.46-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='45')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.47-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='46')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.45-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 849000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='44')])], id=157998, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 816000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 18, 59, 952000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 914000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.40-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='39')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.38-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='37')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.BUY_TO_CLOSE: 'Buy to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.39-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='38')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.41-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 804000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='40')])], id=157995, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 772000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 18, 5, 56, 911000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.DAY: 'Day'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 605000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05920000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.34-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='33')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206P05950000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.36-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.08'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='2', ext_exec_id='35')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.37-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='3', ext_exec_id='36')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241202.35-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 501000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='34')])], id=157991, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 467000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 12, 2, 17, 59, 11, 601000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 749000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.197-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='196')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06100000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.196-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='195')])], id=155520, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 617000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 745000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 170000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C05900000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.195-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='194')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.194-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='193')])], id=155519, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 25000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 166000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155135, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 51000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155134, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 475000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155133, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 872000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155132, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 57000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None)]

# %%
session.destroy()

# %% [markdown]
# ## Alternative Path to send order by hand

# %%
leg6000 = op_cs.build_leg(Decimal('1'), OrderAction.SELL_TO_OPEN)
leg6030 = op_cb.build_leg(Decimal('1'), OrderAction.BUY_TO_OPEN)

# %%
order = NewOrder(
    time_in_force=OrderTimeInForce.GTD,
    order_type=OrderType.LIMIT,
    legs=[leg6000, leg6030],
    price=Decimal('0.05')
    )

# %%
order_response = account.place_order(session, order)

# %%
order_response
# Out:
# PlacedOrderResponse(buying_power_effect=BuyingPowerEffect(change_in_margin_requirement=Decimal('-3000.0'), change_in_buying_power=Decimal('-2998.562'), current_buying_power=Decimal('1000000.0'), new_buying_power=Decimal('997001.438'), isolated_order_margin_requirement=Decimal('-3000.0'), is_spread=True, impact=Decimal('2998.562'), effect=<PriceEffect.DEBIT: 'Debit'>), order=PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTD: 'GTD'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.RECEIVED: 'Received'>, cancellable=True, editable=True, edited=False, updated_at=datetime.datetime(1970, 1, 1, 0, 0, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06060000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241206C06090000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=-1, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=None, reject_reason=None, user_id=None, username=None, terminal_at=None, complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None), fee_calculation=FeeCalculation(regulatory_fees=Decimal('-0.062'), clearing_fees=Decimal('-0.2'), commission=Decimal('-2.0'), proprietary_index_option_fees=Decimal('-1.3'), total_fees=Decimal('-3.562')), warnings=[], errors=None)

# %%
account.get_order_history(session)
# Out:
# [PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 749000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.SELL_TO_CLOSE: 'Sell to Close'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.197-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='196')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06100000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.196-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 647000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='195')])], id=155520, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 617000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 42, 52, 745000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.FILLED: 'Filled'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 170000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C05900000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.195-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.06'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='1', ext_exec_id='194')]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241115C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('0'), fills=[FillInfo(fill_id='2_TW::TEST_A1::20241115.194-TEST_FILL', quantity=Decimal('1'), fill_price=Decimal('0.01'), filled_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 67000, tzinfo=TzInfo(UTC)), destination_venue='TEST_A', ext_group_fill_id='0', ext_exec_id='193')])], id=155519, size=Decimal('1'), price=Decimal('0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 25000, tzinfo=TzInfo(UTC)), reject_reason=None, user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 15, 19, 37, 48, 166000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155135, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 53000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 47, 51000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155134, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 477000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 43, 475000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155133, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 873000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 872000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None),
#  PlacedOrder(account_number='5WX24638', time_in_force=<OrderTimeInForce.GTC: 'GTC'>, order_type=<OrderType.LIMIT: 'Limit'>, underlying_symbol='SPX', underlying_instrument_type=<InstrumentType.EQUITY: 'Equity'>, status=<OrderStatus.REJECTED: 'Rejected'>, cancellable=False, editable=False, edited=False, updated_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), legs=[Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05960000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114P05930000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C05970000', action=<OrderAction.SELL_TO_OPEN: 'Sell to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[]), Leg(instrument_type=<InstrumentType.EQUITY_OPTION: 'Equity Option'>, symbol='SPXW  241114C06000000', action=<OrderAction.BUY_TO_OPEN: 'Buy to Open'>, quantity=Decimal('1'), remaining_quantity=Decimal('1'), fills=[])], id=155132, size=Decimal('1'), price=Decimal('-0.05'), gtc_date=None, value=None, stop_trigger=None, contingent_status=None, confirmation_status=None, cancelled_at=None, cancel_user_id=None, cancel_username=None, replacing_order_id=None, replaces_order_id=None, in_flight_at=None, live_at=None, received_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 58000, tzinfo=TzInfo(UTC)), reject_reason='Trading of SPXW  241114P05960000 is not supported', user_id=None, username=None, terminal_at=datetime.datetime(2024, 11, 14, 20, 0, 39, 57000, tzinfo=TzInfo(UTC)), complex_order_id=None, complex_order_tag=None, preflight_id=None, order_rule=None)]

# %%
session.destroy()
